# %%
import pandas as pd

dff = pd.read_csv('./card_info/card_price.csv')
dff.head()
# Out:
#      index              card_name  \
# 0  130/100          ナンジャモのハラバリーex
# 1  131/100   Nのゾロアークex(通常版:縞模様あり)
# 2  131/100  Nのゾロアークex(エラー版:縞模様なし)
# 3  132/100              スパイクエネルギー
# 4  233/187               テツノイサハex
#
#                                              img_src rarity  p_20250201  \
# 0  https://img.yuyu-tei.jp/card_image/poc/100_140...     UR     17800.0
# 1  https://img.yuyu-tei.jp/card_image/poc/100_140...     UR      8980.0
# 2  https://img.yuyu-tei.jp/card_image/poc/100_140...     UR     69800.0
# 3  https://img.yuyu-tei.jp/card_image/poc/100_140...     UR       980.0
# 4  https://img.yuyu-tei.jp/card_image/poc/100_140...     UR       680.0
#
#    p_20250202  p_20250203  p_20250204  p_20250205  p_20250206  ...  \
# 0     17800.0     12800.0     12800.0     12800.0     12800.0  ...
# 1      8980.0      6980.0      6980.0      6980.0      6980.0  ...
# 2     69800.0     69800.0     69800.0     69800.0     69800.0  ...
# ...

# %%
dff.to_csv('./card_info/card_price.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv("/Users/vaibhavgupta/Desktop/pokemon_card_analysis/card_info/base_card_info.csv")
df.columns
# Out:
# Index(['index', 'rarity', 'card_name', 'img_src', 'pack'], dtype='object')

# %%
df = df.iloc[:, :-1]  # Drops the last column
df.to_csv("cleaned_file.csv", index=False)

# %%
df.columns
# Out:
# Index(['index', 'rarity', 'card_name', 'img_src'], dtype='object')
