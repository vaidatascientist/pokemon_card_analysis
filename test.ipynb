# %%
import pandas as pd

df = pd.read_csv('./card_info/base_card_info.csv')
df.head()
# Out:
#      index rarity              card_name  \
# 0  130/100     UR          ナンジャモのハラバリーex
# 1  131/100     UR   Nのゾロアークex(通常版:縞模様あり)
# 2  131/100     UR  Nのゾロアークex(エラー版:縞模様なし)
# 3  132/100     UR              スパイクエネルギー
# 4  233/187     UR               テツノイサハex
#
#                                              img_src
# 0  https://img.yuyu-tei.jp/card_image/poc/100_140...
# 1  https://img.yuyu-tei.jp/card_image/poc/100_140...
# 2  https://img.yuyu-tei.jp/card_image/noimage_100...
# 3  https://img.yuyu-tei.jp/card_image/poc/100_140...
# 4  https://img.yuyu-tei.jp/card_image/poc/100_140...

# %%
import pandas as pd

dff = pd.read_csv('./card_info/card_price.csv')
dff.head()
# Out:
#      index              card_name  p_20250201  p_20250202  p_20250203
# 0  130/100          ナンジャモのハラバリーex       17800       17800       12800
# 1  131/100   Nのゾロアークex(通常版:縞模様あり)        8980        8980        6980
# 2  131/100  Nのゾロアークex(エラー版:縞模様なし)       69800       69800       69800
# 3  132/100              スパイクエネルギー         980         980         980
# 4  233/187               テツノイサハex         680         680         680

# %%
dff.drop(columns=['level_0'], inplace=True)
dff.head()
# Out:
#      index              card_name  p_20250201  p_20250202  p_20250203
# 0  130/100          ナンジャモのハラバリーex       17800       17800       12800
# 1  131/100   Nのゾロアークex(通常版:縞模様あり)        8980        8980        6980
# 2  131/100  Nのゾロアークex(エラー版:縞模様なし)       69800       69800       69800
# 3  132/100              スパイクエネルギー         980         980         980
# 4  233/187               テツノイサハex         680         680         680

# %%
dff.to_csv('./card_info/card_price.csv', index=False)
